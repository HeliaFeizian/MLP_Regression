# %% [markdown]
# # How to use MLP Classifier and Regressor in Python

# %%
import pandas as pd
from sklearn import datasets
from sklearn import metrics
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
df = pd.read_csv('.../BTC-USD.csv')
X = df[['High','Low']].to_numpy()
y = df['Close'].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
model = MLPRegressor()
model.fit(X_train, y_train)
# Out:
# MLPRegressor()

# %%
# make predictions
expected_y  = y_test
predicted_y = model.predict(X_test)

# %%
predicted_y
# Out:
# array([36029.01379479, 38907.44133785, 21188.58677919, 23190.22219422,
#        19643.46283361, 47070.79815936, 32403.41178375, 19676.94348274,
#        44526.58523312, 20025.40719451, 48041.07023406, 17268.50999588,
#        20632.41088648, 17259.64767742, 46928.16787692, 40535.08516521,
#        18266.8851749 , 30572.35030477, 16492.6057111 , 16626.60671192,
#        20827.05066164, 22038.64581064, 19422.20859365, 20237.05159065,
#        27913.84248052, 17727.2420624 , 22201.57575569, 21782.31799459,
#        47674.69741542, 30527.16067571, 22172.48339792, 19143.90353199,
#        23976.49562555, 40650.04010514, 42975.22317005, 51441.07931443,
#        37288.31096687, 30751.56613042, 30684.29164719, 51077.72532114,
#        16769.97208968, 23411.03674196, 29884.3215812 , 38255.34907871,
#        19530.4385114 , 38597.03372896, 38539.46638078, 43226.97250366,
#        23485.79483923, 38758.85722055, 19254.18217655, 29661.63623858,
#        35394.3289237 , 17303.87134141, 23145.05745889, 16560.14137422,
#        19615.17185594, 43797.83589606, 19353.87042356, 41713.53563492,
#        29126.96602723, 22299.43172119, 42573.70778635, 39129.2600739 ,
#        19865.33414423, 45037.69875963, 19437.04206143, 17239.93954523,
#        45119.79231611, 23499.91479111, 23733.37231421, 44077.32641628,
#        19676.14878307, 20258.04616003])

# %%
expected_y
# Out:
# array([36276.804688, 37709.785156, 20260.019531, 23164.628906,
#        19312.095703, 46880.277344, 30296.953125, 19345.572266,
#        44118.445313, 19269.367188, 47345.21875 , 17034.292969,
#        19970.556641, 17233.474609, 45555.992188, 40127.183594,
#        17815.650391, 29862.917969, 16217.322266, 16610.707031,
#        20495.773438, 21731.117188, 19053.740234, 19701.210938,
#        26762.648438, 17781.318359, 22930.548828, 21395.019531,
#        47686.8125  , 30467.488281, 20877.552734, 19413.550781,
#        23809.486328, 40122.15625 , 42250.550781, 50429.859375,
#        37154.601563, 30111.998047, 31155.478516, 50809.515625,
#        16444.626953, 22714.978516, 30314.333984, 36952.984375,
#        19139.535156, 37296.570313, 36457.316406, 43099.699219,
#        22961.279297, 38062.039063, 19222.671875, 29655.585938,
#        36654.328125, 17206.4375  , 22630.957031, 16444.982422,
#        19784.726563, 43177.398438, 18937.011719, 41502.75    ,
#        28814.900391, 22370.449219, 42190.652344, 38737.269531,
#        20231.261719, 43565.113281, 20553.271484, 17088.660156,
#        44500.828125, 23314.199219, 23164.318359, 44575.203125,
#        19550.757813, 20127.576172])

# %%
metrics.mean_squared_log_error(expected_y, predicted_y)
# Out:
# 0.0005479061203473821

# %%
plt.figure(figsize=(10,10))
sns.regplot(expected_y, predicted_y, fit_reg=True, scatter_kws={"s": 100})
# Out:
# C:\Users\ffeiz\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
